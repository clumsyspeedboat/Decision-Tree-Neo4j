# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.8-py2.py3-none-any.whl (244 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_excel('dt_analysis.xlsx', index_col=0)
df = pd.read_csv('dt_analysis.csv')

# %%
#df.drop(df.columns[10:], axis=1, inplace=True)
df.head()
# Out:
#   decision_tree                   dataset language splitting_criterion  rows  \
# 0            d1  heart failure prediction        r                gini   299
# 1            d2  heart failure prediction        r          gain ratio   299
# 2            d3  heart failure prediction        r          gain ratio   299
# 3            d4  heart failure prediction   python                gini   299
# 4            d5  heart failure prediction   python           info gain   299
#
#    columns  leaf_nodes  depth  accuracy  generation_time  prediction_time
# 0       13           4      4     80.41         0.010996         0.004000
# 1       13           7      7     78.35         0.084039         0.020002
# 2       13           6      5     80.41         0.014001         0.007999
# 3       13          28      9     67.01         0.006842         0.002096
# 4       13          25      9     74.22         0.002834         0.001789

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   decision_tree        42 non-null     object
#  1   dataset              42 non-null     object
#  2   language             42 non-null     object
#  3   splitting_criterion  42 non-null     object
#  4   rows                 42 non-null     int64
#  5   columns              42 non-null     int64
#  6   leaf_nodes           42 non-null     int64
#  7   depth                42 non-null     int64
#  8   accuracy             42 non-null     float64
#  9   generation_time      42 non-null     float64
#  10  prediction_time      42 non-null     float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 3.7+ KB

# %%
acc_df = df.groupby(['language']).mean()['accuracy']
acc_df.plot.line()
# Out:
# <AxesSubplot:xlabel='language'>

# %%
fig_dims = (4, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.set(font_scale=1)
sns.lineplot('language','accuracy',  data =df, hue='dataset', ax=ax)
# Out:
# C:\Users\Nasim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='language', ylabel='accuracy'>

# %%
fig_dims = (4, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.set(font_scale=1)
sns.lineplot('splitting_criterion','accuracy',  data =df, hue='dataset', ax=ax)
# Out:
# C:\Users\Nasim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='splitting_criterion', ylabel='accuracy'>

# %%
sns.displot(data=df, x="generation_time",col= "dataset", kde=True)

# %%
sns.displot(data=df, x="generation_time",col= "splitting_criterion", kde=True)

# %%
sns.set(font_scale=1.3)
fig_dims = (11, 6)
fig, ax =plt.subplots(1,2, figsize=fig_dims)
plt.legend(fontsize='x-large', title_fontsize='40')
#sns.countplot(df['batting'], ax=ax[0])
fig1=sns.lineplot('language','accuracy',  data =df, hue='dataset', ax=ax[0], legend=True)
plt.legend(loc='best')
#plt.setp(fig1.get_legend().get_texts(), fontsize='10') 

fig2 = sns.lineplot('splitting_criterion','accuracy',  data =df, hue='dataset', ax=ax[1], legend=False)
fig.show()
# Out:
# No handles with labels found to put in legend.
# C:\Users\Nasim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.
# C:\Users\Nasim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nasim\AppData\Local\Temp/ipykernel_13512/2905968942.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
sns.catplot(data=df, kind="violin", x="splitting_criterion", y="generation_time")

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
fig.suptitle('Violin plot generation time')

sns.violinplot(ax = axes[0], data=df, kind="violin", x="splitting_criterion", y="generation_time")
#axes[0].set_title("HELLO")

violin2 = sns.violinplot(ax = axes[1], data=df, kind="violin", x="dataset", y="generation_time")
#axes[1].set_title("world")
violin2.set_xticklabels(['heart failure','metaprotein','flu'])
# Out:
# [Text(0, 0, 'heart failure'), Text(1, 0, 'metaprotein'), Text(2, 0, 'flu')]

# %%
sns.catplot(data=df, kind="violin", x="dataset", y="generation_time")

# %%
neo_df = df[df['language']=='neo4j_csv']
neo_db_df = df[df['language']=='neo4j_db']
neo_df2 = neo_df.append(neo_db_df, ignore_index=True)
neo_df2
#sns.catplot(data=neo_df2, kind="violin", x="neo4j_csv", y="generation_time")
# Out:
#    decision_tree                   dataset   language splitting_criterion  \
# 0             d9  heart failure prediction  neo4j_csv                gini
# 1            d10  heart failure prediction  neo4j_csv           info gain
# 2            d11  heart failure prediction  neo4j_csv          gain ratio
# 3            d23               metaprotein  neo4j_csv                gini
# 4            d24               metaprotein  neo4j_csv           info gain
# 5            d25               metaprotein  neo4j_csv          gain ratio
# 6            d37                       flu  neo4j_csv                gini
# 7            d38                       flu  neo4j_csv           info gain
# 8            d39                       flu  neo4j_csv          gain ratio
# 9            d12  heart failure prediction   neo4j_db                gini
# 10           d13  heart failure prediction   neo4j_db           info gain
# 11           d14  heart failure prediction   neo4j_db          gain ratio
# 12           d26               metaprotein   neo4j_db                gini
# 13           d27               metaprotein   neo4j_db           info gain
# 14           d28               metaprotein   neo4j_db          gain ratio
# 15           d40                       flu   neo4j_db                gini
# 16           d41                       flu   neo4j_db           info gain
# 17           d42                       flu   neo4j_db          gain ratio
#
#     rows  columns  leaf_nodes  depth  accuracy  generation_time  \
# 0    299       13          12     10     76.29         0.128000
# 1    299       13          11      9     73.20         0.073000
# 2    299       13           8      8     76.29         0.057000
# 3     48       50           5      4     70.83         0.012000
# 4     48       50           5      4     70.83         0.004999
# 5     48       50           5      4     75.00         0.018999
# 6   1485       13          15      6     91.93         0.243000
# 7   1485       13          16      6     91.95         0.068000
# 8   1485       13          15      9     89.30         0.166999
# 9    299       13          12     10     76.29         0.057000
# 10   299       13          10     12     73.20         0.033000
# 11   299       13          12     11     76.29         0.044000
# 12    48       50           5      4     70.83         0.010999
# 13    48       50           5      4     66.67         0.020999
# 14    48       50           5      4     75.00         0.019000
# 15  1485       13          24      4     99.44         0.211999
# 16  1485       13          20      8     91.95         0.074000
# 17  1485       13          15      9     99.46         0.132000
#
#     prediction_time
# 0           0.00100
# 1           0.00100
# 2           0.00100
# 3           0.00001
# 4           0.00001
# 5           0.00001
# 6           0.00200
# 7           0.00100
# 8           0.00100
# 9           0.00000
# 10          0.00100
# 11          0.00100
# 12          0.00001
# 13          0.00001
# 14          0.00001
# 15          0.00400
# 16          0.00200
# 17          0.00300

# %%
sns.catplot(data=neo_df2, kind="violin", x="language", y="generation_time")

# %%
sns.catplot(data=neo_df2, kind="violin", x="language", y="prediction_time")

# %%
sns.catplot(data=neo_df2, kind="swarm", x="language", y="generation_time", hue="dataset", s = 15)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Swarm plot generation & prediction time(in sec)')

g = sns.swarmplot(data=neo_df2, x="language", y="generation_time", hue="dataset", ax = axes[0], s=12, dodge=True)

#sns.violinplot(ax = axes[0], data=neo_df2, kind="violin", x="splitting_criterion", y="generation_time", legend=False)

legend = g.legend()
legend.remove()

g.set_xticklabels(['Neo4j_CSV','Neo4j_DB'], size=16)
g.set(xlabel=None)


h= sns.swarmplot(data=neo_df2, x="language", y="prediction_time", hue="dataset",dodge=True, ax=axes[1], s=12)

h.set_xticklabels(['Neo4j_CSV','Neo4j_DB'], size=16)

h.set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
sns.catplot(data=neo_df2, kind="swarm", x="language", y="prediction_time", hue="dataset", s = 15)

# %%
sns.pairplot(data=df, hue="language", height=2.5)

# %%
java_df_gen_time = df[df['language'] == 'java']['generation_time']

# %%
java_df_gen_time
# Out:
# decision_tree
# d6     0.194
# d7     0.072
# d8     0.069
# d20    0.068
# d21    0.025
# d22    0.028
# d34    0.369
# d36    0.151
# d35    0.210
# Name: generation_time, dtype: float64

# %%
python_df_gen_time = df[df['language'] == 'python'].sort_values('generation_time', ascending = True)['generation_time']

# %%
#r_df_gen_time = df[df['language'] == 'r'].sort_values('generation_time', ascending = True)['generation_time']
r_df_gen_time = df[df['language'] == 'r']['generation_time']
r_df_gen_time
# Out:
# decision_tree
# d1     0.010996
# d2     0.084039
# d3     0.014001
# d15    0.005998
# d16    0.038003
# d17    0.022741
# d29    0.014999
# d30    0.054293
# d31    0.210996
# Name: generation_time, dtype: float64
